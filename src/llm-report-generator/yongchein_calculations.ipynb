# %% [markdown]
# ## Package import

# %%
import os
import pandas as pd
from datetime import datetime, date, time, timedelta
from pprint import pprint

# %% [markdown]
# ## Data import

# %%
df_data = pd.read_excel(f'Fixed_Synthetic_Data.xlsx')

# %%
print(df_data.columns.tolist())
# Out:
# ['Instance', 'OrderNo', 'ParentOrderNo', 'RootParentOrderNo', 'CreateDate', 'DeleteDate', 'AccID', 'AccCode', 'BuySell', 'Side', 'OrderSide', 'SecID', 'SecCode', 'Exchange', 'Destination', 'Quantity', 'PriceMultiplier', 'Price', 'Value', 'ValueMultiplier', 'DoneVolume', 'DoneValue', 'Currency', 'OrderType', 'PriceInstruction', 'TimeInForce', 'Lifetime', 'ClientOrderID', 'SecondaryClientOrderID', 'DestOrderNo', 'ExtDestOrderNo', 'DestUserID', 'OrderGiver', 'OrderTakerUserCode', 'IntermediaryID', 'OriginOfOrder', 'OrderCapacity', 'DirectedWholesale', 'ExecutionVenue', 'ExecutionInstructionsRaw']

# %%
df_data['BuySell'].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %%
df_data['BuySell'] = df_data['BuySell'].replace(['B'], 'Buy')
df_data['BuySell'] = df_data['BuySell'].replace(['S'], 'Sell')
df_data
# Out:
#         Instance   OrderNo  ParentOrderNo  RootParentOrderNo  \
# 0     BURGERKING  72372283       55096261          468008605
# 1     BURGERKING  72371760       46567211          651932639
# 2     BURGERKING  72375159       32939774          472062144
# 3     BURGERKING  72371424        5227412          319309289
# 4     BURGERKING  72370582         839479          670284316
# ...          ...       ...            ...                ...
# 4995  BURGERKING  72374955       64226583          193715239
# 4996  BURGERKING  72372231       25985994          534963672
# 4997  BURGERKING  72373891       60590952          167286294
# 4998  BURGERKING  72375157       14166422          147565764
# 4999  BURGERKING  72370328       55288793          252371712
#
#                          CreateDate                     DeleteDate  AccID  \
# 0     2024-02-01 13:07:07.732746549  2024-02-01 16:32:35.948789757     85
# 1     2024-02-01 16:11:11.047009401  2024-02-01 16:37:39.237447489    144
# 2     2024-02-01 17:10:21.384276855  2024-02-01 17:14:02.915783156     85
# 3     2024-02-01 16:03:10.476495299  2024-02-01 14:51:23.435887177    119
# 4     2024-02-01 15:50:50.005601120  2024-02-01 18:38:37.945989197      9
# ...                             ...                            ...    ...
# 4995  2024-02-01 12:43:59.962792558  2024-02-01 17:11:14.422084416     43
# 4996  2024-02-01 17:12:43.593918783  2024-02-01 17:28:05.384276855    150
# 4997  2024-02-01 14:24:36.516903380  2024-02-01 17:09:46.805361072    155
# 4998  2024-02-01 12:26:15.842368473  2024-02-01 15:20:15.551110222    165
# 4999  2024-02-01 12:37:57.083016603  2024-02-01 18:01:54.048409681     74
#
#       AccCode BuySell  Side  ... ExtDestOrderNo  DestUserID OrderGiver  \
# 0       ROBBO     Buy     1  ...   27Y19YXOGV80        4770  robbotest
# 1        NOEL     Buy     1  ...   27Y19YXOG7UF        4468    robtest
# 2       ROBBO     Buy     2  ...   27Y19YXOG7UB        4619    robtest
# 3       ROBBO    Sell     4  ...   27Y19YXOG7UF         964  robbotest
# 4          ZM     Buy     2  ...   17Y19YXOID1C         488    robtest
# ...       ...     ...   ...  ...            ...         ...        ...
# 4995    ROBBO    Sell     3  ...   27Y19YXOGV56        3696    robtest
# 4996  UNKNOWN     Buy     2  ...   27Y19YXOG7UF        3136  robbotest
# 4997       ZM     Buy     3  ...   27Y19YXOGV80        3315  robbotest
# 4998  UNKNOWN    Sell     4  ...   17Y19YXOID3O        4679    robtest
# 4999     NOEL    Sell     1  ...   27Y19YXOG7UA         541  robbotest
#
#      OrderTakerUserCode IntermediaryID  OriginOfOrder  OrderCapacity  \
# 0         admin@IRETEST   71423.783724     ROBTESTING      Principal
# 1       admin@ROBBOTEST   12599.794665             39         Agency
# 2       admin@ROBBOTEST   53707.634919           NOEL      Principal
# 3       admin@ROBBOTEST  105870.738240             HK      Principal
# 4       admin@ROBBOTEST   29797.336732     ROBTESTING         Agency
# ...                 ...            ...            ...            ...
# 4995      admin@IRETEST   74298.605690             HK         Agency
# 4996      admin@IRETEST   59933.428616           NOEL      Principal
# 4997    admin@ROBBOTEST   40066.523329             HK      Principal
# 4998    admin@ROBBOTEST   21172.604124             HK      Principal
# 4999    admin@ROBBOTEST   88125.857056           NOEL         Agency
#
#       DirectedWholesale  ExecutionVenue  \
# 0                     N        0.148755
# 1                     N        0.934947
# 2                     N        0.889763
# 3                     N        0.737766
# 4                     N        0.499592
# ...                 ...             ...
# 4995                  N        0.477659
# 4996                  N        0.334415
# 4997                  N        0.716491
# 4998                  N        0.747413
# 4999                  N        0.364861
#
#                                ExecutionInstructionsRaw
# 0                       IADW(N), IOCA(Agency), IAOR(39)
# 1     IAOR(ROBTESTING), IOCA(Agency), IADW(N), IAIN(...
# 2               IAOR(TESTINGACC), IOCA(Agency), IADW(N)
# 3        IADW(N), IOCA(Agency), IAOR(NOEL), IAIN(54321)
# 4               IAOR(TESTINGACC), IOCA(Agency), IADW(N)
# ...                                                 ...
# 4995         IAOR(TESTINGACC), IOCA(Principal), IADW(N)
# 4996  IAOR(ROBTESTING), IOCA(Agency), IADW(N), IAIN(...
# 4997                 IADW(N), IOCA(Agency), IAOR(34976)
# 4998                           IOCA(Principal), IADW(N)
# 4999              IOAR(NOEL), IOCA(Agency), IAIN(12345)
#
# [5000 rows x 40 columns]

# %%
df_data.shape
# Out:
# (5000, 40)

# %% [markdown]
# ## Calculating summarised data from data visualisations

# %%
def calculate_percentage_difference(current, historical):
    if historical == 0:  # Avoid division by zero
        return float('inf')  # or handle it as needed
    return round(((current - historical) / historical) * 100, 2)

# %% [markdown]
# ### Config

# %%
calculation_date = datetime(2024, 2, 1)  # Can be loaded in via a configuration file
historical_start_date = datetime(2024, 2, 1)  # Can be loaded in via a configuration file
historical_end_date = datetime(2024, 2, 1)  # Can be loaded in via a configuration file
historical_num_of_days = (historical_end_date - historical_start_date).days + 1

# %%
print(historical_num_of_days)
# Out:
# 1

# %% [markdown]
# ### Filter data

# %%
calculation_data = df_data[df_data['CreateDate'].dt.floor('D') == calculation_date]
calculation_data.shape

# %%
historical_data = df_data[
    (df_data['CreateDate'].dt.floor('D') >= historical_start_date) & 
    (df_data['CreateDate'].dt.floor('D') <= historical_end_date)
]
historical_data.shape
# Out:
# (5000, 40)

# %% [markdown]
# ### bi_viz_1_overview

# %%
bi_viz_1_overview = {
    'current': {
        'total_number_of_orders': calculation_data.shape[0],
        'total_volume_of_orders': calculation_data['DoneVolume'].sum(),
        'total_value_of_orders': round((calculation_data['Value'] * calculation_data['ValueMultiplier']).sum(), 2),
    },
    'average_historical': {
        'total_number_of_orders': int(historical_data.shape[0] / historical_num_of_days),
        'total_volume_of_orders': int(historical_data['DoneVolume'].sum() / historical_num_of_days),
        'total_value_of_orders': round(((historical_data['Value'] * historical_data['ValueMultiplier']).sum()) / historical_num_of_days, 2),
    },
    'percentage_difference': {
        'in_total_orders': calculate_percentage_difference(
            calculation_data.shape[0],
            int(historical_data.shape[0] / historical_num_of_days)
        ),
        'in_total_volume': calculate_percentage_difference(
            calculation_data['DoneVolume'].sum(),
            int(historical_data['DoneVolume'].sum() / historical_num_of_days)
        ),
        'in_total_value': calculate_percentage_difference(
            round((calculation_data['Value'] * calculation_data['ValueMultiplier']).sum(), 2),
            round(((historical_data['Value'] * historical_data['ValueMultiplier']).sum()) / historical_num_of_days, 2)
        ),
    }
}

# Pretty print the results
pprint(bi_viz_1_overview)
# Out:
# {'current': {'total_number_of_orders': 5000,
#              'total_value_of_orders': 33277305.38,
#              'total_volume_of_orders': 39937087},
#  'historical': {'total_number_of_orders': 5000,
#                 'total_value_of_orders': 33277305.38,
#                 'total_volume_of_orders': 39937087},
#  'percentage_difference': {'in_total_orders': 0.0,
#                            'in_total_value': 0.0,
#                            'in_total_volume': 0.0}}

# %% [markdown]
# ### bi_viz_2_sector

# %%
# bi_viz_2_sector = {}

# for sec in df_data['SecCode'].unique():
#     bi_viz_2_sector[sec] = {}
    
#     # Current data calculations
#     bi_viz_2_sector[sec][f'number_of_buy_orders_for_{sec}_sector'] = calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts().get('Buy', 0)
#     bi_viz_2_sector[sec][f'percentage_of_buy_orders_for_{sec}_sector'] = round(calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Buy', 0) * 100, 2)
#     bi_viz_2_sector[sec][f'number_of_sell_orders_for_{sec}_sector'] = calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts().get('Sell', 0)
#     bi_viz_2_sector[sec][f'percentage_of_sell_orders_for_{sec}_sector'] = round(calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Sell', 0) * 100, 2)
#     bi_viz_2_sector[sec][f'total_number_of_orders_for_{sec}_sector'] = calculation_data[calculation_data['SecCode'] == sec].shape[0]
    
#     # Historical data calculations
#     bi_viz_2_sector[sec][f'historical_number_of_buy_orders_for_{sec}_sector'] = historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts().get('Buy', 0)
#     bi_viz_2_sector[sec][f'historical_percentage_of_buy_orders_for_{sec}_sector'] = round(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Buy', 0) * 100, 2)
#     bi_viz_2_sector[sec][f'historical_number_of_sell_orders_for_{sec}_sector'] = historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts().get('Sell', 0)
#     bi_viz_2_sector[sec][f'historical_percentage_of_sell_orders_for_{sec}_sector'] = round(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Sell', 0) * 100, 2)
#     bi_viz_2_sector[sec][f'historical_total_number_of_orders_for_{sec}_sector'] = historical_data[historical_data['SecCode'] == sec].shape[0]

#     # Pecentage difference
#     bi_viz_2_sector[sec][f'percentage_difference_in_number_of_buy_orders_for_{sec}_sector'] = calculate_percentage_difference(
#         bi_viz_2_sector[sec][f'number_of_buy_orders_for_{sec}_sector'],
#         bi_viz_2_sector[sec][f'historical_number_of_buy_orders_for_{sec}_sector']
#     )  
#     bi_viz_2_sector[sec][f'percentage_difference_in_percentage_of_buy_orders_for_{sec}_sector'] = calculate_percentage_difference(
#         bi_viz_2_sector[sec][f'percentage_of_buy_orders_for_{sec}_sector'],
#         bi_viz_2_sector[sec][f'historical_percentage_of_buy_orders_for_{sec}_sector']
#     )
#     bi_viz_2_sector[sec][f'percentage_difference_in_number_of_sell_orders_for_{sec}_sector'] = calculate_percentage_difference(
#         bi_viz_2_sector[sec][f'number_of_sell_orders_for_{sec}_sector'],
#         bi_viz_2_sector[sec][f'historical_number_of_sell_orders_for_{sec}_sector']
#     )
#     bi_viz_2_sector[sec][f'percentage_difference_in_percentage_of_sell_orders_for_{sec}_sector'] = calculate_percentage_difference(
#         bi_viz_2_sector[sec][f'percentage_of_sell_orders_for_{sec}_sector'],
#         bi_viz_2_sector[sec][f'historical_percentage_of_sell_orders_for_{sec}_sector']
#     )

# pprint(bi_viz_2_sector)


bi_viz_2_sector = {}

for sec in df_data['SecCode'].unique():
    bi_viz_2_sector[sec] = {
        'current': {
            'number_of_buy_orders': calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts().get('Buy', 0),
            'percentage_of_buy_orders': round(calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Buy', 0) * 100, 2),
            'number_of_sell_orders': calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts().get('Sell', 0),
            'percentage_of_sell_orders': round(calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Sell', 0) * 100, 2),
            'total_number_of_orders': calculation_data[calculation_data['SecCode'] == sec].shape[0],
        },
        'average_historical': {
            'number_of_buy_orders': int(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts().get('Buy', 0) / historical_num_of_days),
            'percentage_of_buy_orders': round(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Buy', 0) * 100, 2),
            'number_of_sell_orders': historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts().get('Sell', 0),
            'percentage_of_sell_orders': round(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Sell', 0) * 100, 2),
            'total_number_of_orders': int(historical_data[historical_data['SecCode'] == sec].shape[0] / historical_num_of_days),
        },
        'percentage_difference': {
            'in_number_of_buy_orders': calculate_percentage_difference(
                calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts().get('Buy', 0),
                int(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts().get('Buy', 0) / historical_num_of_days)
            ),
            'in_percentage_of_buy_orders': calculate_percentage_difference(
                round(calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Buy', 0) * 100, 2),
                round(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Buy', 0) * 100, 2)
            ),
            'in_number_of_sell_orders': calculate_percentage_difference(
                calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts().get('Sell', 0),
                int(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts().get('Sell', 0))
            ),
            'in_percentage_of_sell_orders': calculate_percentage_difference(
                round(calculation_data[calculation_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Sell', 0) * 100, 2),
                round(historical_data[historical_data['SecCode'] == sec]['BuySell'].value_counts(normalize=True).get('Sell', 0) * 100, 2)
            ),
            'in_total_number_of_orders': calculate_percentage_difference(
                calculation_data[calculation_data['SecCode'] == sec].shape[0],
                int(historical_data[historical_data['SecCode'] == sec].shape[0] / historical_num_of_days)
            ),
        }
    }

pprint(bi_viz_2_sector)
# Out:
# {'ACDC': {'current': {'number_of_buy_orders': 308,
#                       'number_of_sell_orders': 336,
#                       'percentage_of_buy_orders': 47.83,
#                       'percentage_of_sell_orders': 52.17,
#                       'total_number_of_orders': 644},
#           'historical': {'number_of_buy_orders': 308,
#                          'number_of_sell_orders': 336,
#                          'percentage_of_buy_orders': 47.83,
#                          'percentage_of_sell_orders': 52.17,
#                          'total_number_of_orders': 644},
#           'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                     'in_number_of_sell_orders': 0.0,
#                                     'in_percentage_of_buy_orders': 0.0,
#                                     'in_percentage_of_sell_orders': 0.0,
#                                     'in_total_number_of_orders': 0.0}},
#  'BHP': {'current': {'number_of_buy_orders': 321,
#                      'number_of_sell_orders': 314,
#                      'percentage_of_buy_orders': 50.55,
#                      'percentage_of_sell_orders': 49.45,
#                      'total_number_of_orders': 635},
#          'historical': {'number_of_buy_orders': 321,
#                         'number_of_sell_orders': 314,
#                         'percentage_of_buy_orders': 50.55,
#                         'percentage_of_sell_orders': 49.45,
#                         'total_number_of_orders': 635},
#          'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                    'in_number_of_sell_orders': 0.0,
#                                    'in_percentage_of_buy_orders': 0.0,
#                                    'in_percentage_of_sell_orders': 0.0,
#                                    'in_total_number_of_orders': 0.0}},
#  'CBA': {'current': {'number_of_buy_orders': 342,
#                      'number_of_sell_orders': 322,
#                      'percentage_of_buy_orders': 51.51,
#                      'percentage_of_sell_orders': 48.49,
#                      'total_number_of_orders': 664},
#          'historical': {'number_of_buy_orders': 342,
#                         'number_of_sell_orders': 322,
#                         'percentage_of_buy_orders': 51.51,
#                         'percentage_of_sell_orders': 48.49,
#                         'total_number_of_orders': 664},
#          'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                    'in_number_of_sell_orders': 0.0,
#                                    'in_percentage_of_buy_orders': 0.0,
#                                    'in_percentage_of_sell_orders': 0.0,
#                                    'in_total_number_of_orders': 0.0}},
#  'IRE': {'current': {'number_of_buy_orders': 318,
#                      'number_of_sell_orders': 302,
#                      'percentage_of_buy_orders': 51.29,
#                      'percentage_of_sell_orders': 48.71,
#                      'total_number_of_orders': 620},
#          'historical': {'number_of_buy_orders': 318,
#                         'number_of_sell_orders': 302,
#                         'percentage_of_buy_orders': 51.29,
#                         'percentage_of_sell_orders': 48.71,
#                         'total_number_of_orders': 620},
#          'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                    'in_number_of_sell_orders': 0.0,
#                                    'in_percentage_of_buy_orders': 0.0,
#                                    'in_percentage_of_sell_orders': 0.0,
#                                    'in_total_number_of_orders': 0.0}},
#  'JBH': {'current': {'number_of_buy_orders': 283,
#                      'number_of_sell_orders': 340,
#                      'percentage_of_buy_orders': 45.43,
#                      'percentage_of_sell_orders': 54.57,
#                      'total_number_of_orders': 623},
#          'historical': {'number_of_buy_orders': 283,
#                         'number_of_sell_orders': 340,
#                         'percentage_of_buy_orders': 45.43,
#                         'percentage_of_sell_orders': 54.57,
#                         'total_number_of_orders': 623},
#          'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                    'in_number_of_sell_orders': 0.0,
#                                    'in_percentage_of_buy_orders': 0.0,
#                                    'in_percentage_of_sell_orders': 0.0,
#                                    'in_total_number_of_orders': 0.0}},
#  'NXT': {'current': {'number_of_buy_orders': 292,
#                      'number_of_sell_orders': 309,
#                      'percentage_of_buy_orders': 48.59,
#                      'percentage_of_sell_orders': 51.41,
#                      'total_number_of_orders': 601},
#          'historical': {'number_of_buy_orders': 292,
#                         'number_of_sell_orders': 309,
#                         'percentage_of_buy_orders': 48.59,
#                         'percentage_of_sell_orders': 51.41,
#                         'total_number_of_orders': 601},
#          'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                    'in_number_of_sell_orders': 0.0,
#                                    'in_percentage_of_buy_orders': 0.0,
#                                    'in_percentage_of_sell_orders': 0.0,
#                                    'in_total_number_of_orders': 0.0}},
#  'PEN': {'current': {'number_of_buy_orders': 313,
#                      'number_of_sell_orders': 303,
#                      'percentage_of_buy_orders': 50.81,
#                      'percentage_of_sell_orders': 49.19,
#                      'total_number_of_orders': 616},
#          'historical': {'number_of_buy_orders': 313,
#                         'number_of_sell_orders': 303,
#                         'percentage_of_buy_orders': 50.81,
#                         'percentage_of_sell_orders': 49.19,
#                         'total_number_of_orders': 616},
#          'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                    'in_number_of_sell_orders': 0.0,
#                                    'in_percentage_of_buy_orders': 0.0,
#                                    'in_percentage_of_sell_orders': 0.0,
#                                    'in_total_number_of_orders': 0.0}},
#  'SIG': {'current': {'number_of_buy_orders': 301,
#                      'number_of_sell_orders': 296,
#                      'percentage_of_buy_orders': 50.42,
#                      'percentage_of_sell_orders': 49.58,
#                      'total_number_of_orders': 597},
#          'historical': {'number_of_buy_orders': 301,
#                         'number_of_sell_orders': 296,
#                         'percentage_of_buy_orders': 50.42,
#                         'percentage_of_sell_orders': 49.58,
#                         'total_number_of_orders': 597},
#          'percentage_difference': {'in_number_of_buy_orders': 0.0,
#                                    'in_number_of_sell_orders': 0.0,
#                                    'in_percentage_of_buy_orders': 0.0,
#                                    'in_percentage_of_sell_orders': 0.0,
#                                    'in_total_number_of_orders': 0.0}}}

# %% [markdown]
# ### bi_viz_3_capacity

# %%
# bi_viz_3_capacity = {}
# capacity_types = ['Agency', 'Principal']
# for capacity in capacity_types:
#     counts = df_data['OrderCapacity'].value_counts()
#     bi_viz_3_capacity[f'number_of_orders_with_{capacity.lower()}_capacity'] = counts.get(capacity, 0)
#     bi_viz_3_capacity[f'percentage_of_orders_with_{capacity.lower()}_capacity'] = round(counts.get(capacity, 0) / len(df_data) * 100, 2)

# bi_viz_3_capacity


bi_viz_3_capacity = {'current': {}, 'average_historical': {}, 'percentage_difference': {}}
capacity_types = ['Agency', 'Principal']
counts = calculation_data['OrderCapacity'].value_counts()
historical_counts = historical_data['OrderCapacity'].value_counts()
for capacity in capacity_types:
    # Current data calculations
    bi_viz_3_capacity['current'][f'number_of_orders_with_{capacity.lower()}_capacity'] = counts.get(capacity, 0)
    bi_viz_3_capacity['current'][f'percentage_of_orders_with_{capacity.lower()}_capacity'] = round(counts.get(capacity, 0) / len(calculation_data) * 100, 2)

    # Historical data calculations
    bi_viz_3_capacity['average_historical'][f'number_of_orders_with_{capacity.lower()}_capacity'] = int(historical_counts.get(capacity, 0) / historical_num_of_days)
    bi_viz_3_capacity['average_historical'][f'percentage_of_orders_with_{capacity.lower()}_capacity'] = round(historical_counts.get(capacity, 0) / len(historical_data) * 100, 2)

    # Percentage difference calculations
    bi_viz_3_capacity['percentage_difference'][f'in_number_of_orders_with_{capacity.lower()}_capacity'] = calculate_percentage_difference(
        bi_viz_3_capacity['current'][f'number_of_orders_with_{capacity.lower()}_capacity'],
        bi_viz_3_capacity['average_historical'][f'number_of_orders_with_{capacity.lower()}_capacity']
    )
    bi_viz_3_capacity['percentage_difference'][f'in_percentage_of_orders_with_{capacity.lower()}_capacity'] = calculate_percentage_difference(
        bi_viz_3_capacity['current'][f'percentage_of_orders_with_{capacity.lower()}_capacity'],
        bi_viz_3_capacity['average_historical'][f'percentage_of_orders_with_{capacity.lower()}_capacity']
    )
pprint(bi_viz_3_capacity)
# Out:
# {'average_historical': {'number_of_orders_with_agency_capacity': 2476,
#                         'number_of_orders_with_principal_capacity': 2524,
#                         'percentage_of_orders_with_agency_capacity': 49.52,
#                         'percentage_of_orders_with_principal_capacity': 50.48},
#  'current': {'number_of_orders_with_agency_capacity': 2476,
#              'number_of_orders_with_principal_capacity': 2524,
#              'percentage_of_orders_with_agency_capacity': 49.52,
#              'percentage_of_orders_with_principal_capacity': 50.48},
#  'percentage_difference': {'in_number_of_orders_with_agency_capacity': 0.0,
#                            'in_number_of_orders_with_principal_capacity': 0.0,
#                            'in_percentage_of_orders_with_agency_capacity': 0.0,
#                            'in_percentage_of_orders_with_principal_capacity': 0.0}}

# %% [markdown]
# ### bi_viz_4_lifetime

# %%
# bi_viz_4_lifetime = {}
# lifetime_types = df_data['Lifetime'].unique()
# for lifetime in lifetime_types:
#     counts = df_data['Lifetime'].value_counts()
#     bi_viz_4_lifetime[f'number_of_orders_with_{lifetime.lower()}_lifetime'] = counts.get(lifetime, 0)
#     bi_viz_4_lifetime[f'percentage_of_orders_with_{lifetime.lower()}_lifetime'] = round(counts.get(lifetime, 0) / len(df_data) * 100, 2)
# bi_viz_4_lifetime


bi_viz_4_lifetime = {'current': {}, 'average_historical': {}, 'percentage_difference': {}}
lifetime_types = df_data['Lifetime'].unique()
counts = calculation_data['Lifetime'].value_counts()
historical_counts = historical_data['Lifetime'].value_counts()
for lifetime in lifetime_types:
    # Current data calculations
    bi_viz_4_lifetime['current'][f'number_of_orders_with_{lifetime.lower()}_lifetime'] = counts.get(lifetime, 0)
    bi_viz_4_lifetime['current'][f'percentage_of_orders_with_{lifetime.lower()}_lifetime'] = round(counts.get(lifetime, 0) / len(calculation_data) * 100, 2)

    # Historical data calculations
    bi_viz_4_lifetime['average_historical'][f'number_of_orders_with_{lifetime.lower()}_lifetime'] = int(
        historical_counts.get(lifetime, 0) / historical_num_of_days
    )
    bi_viz_4_lifetime['average_historical'][f'percentage_of_orders_with_{lifetime.lower()}_lifetime'] = round(
        historical_counts.get(lifetime, 0) / len(historical_data) * 100, 2
    )

    # Percentage difference calculations
    bi_viz_4_lifetime['percentage_difference'][f'in_number_of_orders_with_{lifetime.lower()}_lifetime'] = calculate_percentage_difference(
        bi_viz_4_lifetime['current'][f'number_of_orders_with_{lifetime.lower()}_lifetime'],
        bi_viz_4_lifetime['average_historical'][f'number_of_orders_with_{lifetime.lower()}_lifetime']
    )
    bi_viz_4_lifetime['percentage_difference'][f'in_percentage_of_orders_with_{lifetime.lower()}_lifetime'] = calculate_percentage_difference(
        bi_viz_4_lifetime['current'][f'percentage_of_orders_with_{lifetime.lower()}_lifetime'],
        bi_viz_4_lifetime['average_historical'][f'percentage_of_orders_with_{lifetime.lower()}_lifetime']
    )
pprint(bi_viz_4_lifetime)
# Out:
# {'average_historical': {'number_of_orders_with_end of day_lifetime': 1026,
#                         'number_of_orders_with_fill and kill_lifetime': 977,
#                         'number_of_orders_with_fill or kill_lifetime': 956,
#                         'number_of_orders_with_good till cancel_lifetime': 1035,
#                         'number_of_orders_with_good till time_lifetime': 1006,
#                         'percentage_of_orders_with_end of day_lifetime': 20.52,
#                         'percentage_of_orders_with_fill and kill_lifetime': 19.54,
#                         'percentage_of_orders_with_fill or kill_lifetime': 19.12,
#                         'percentage_of_orders_with_good till cancel_lifetime': 20.7,
#                         'percentage_of_orders_with_good till time_lifetime': 20.12},
#  'current': {'number_of_orders_with_end of day_lifetime': 1026,
#              'number_of_orders_with_fill and kill_lifetime': 977,
#              'number_of_orders_with_fill or kill_lifetime': 956,
#              'number_of_orders_with_good till cancel_lifetime': 1035,
#              'number_of_orders_with_good till time_lifetime': 1006,
#              'percentage_of_orders_with_end of day_lifetime': 20.52,
#              'percentage_of_orders_with_fill and kill_lifetime': 19.54,
#              'percentage_of_orders_with_fill or kill_lifetime': 19.12,
#              'percentage_of_orders_with_good till cancel_lifetime': 20.7,
#              'percentage_of_orders_with_good till time_lifetime': 20.12},
#  'percentage_difference': {'in_number_of_orders_with_end of day_lifetime': 0.0,
#                            'in_number_of_orders_with_fill and kill_lifetime': 0.0,
#                            'in_number_of_orders_with_fill or kill_lifetime': 0.0,
#                            'in_number_of_orders_with_good till cancel_lifetime': 0.0,
#                            'in_number_of_orders_with_good till time_lifetime': 0.0,
#                            'in_percentage_of_orders_with_end of day_lifetime': 0.0,
#                            'in_percentage_of_orders_with_fill and kill_lifetime': 0.0,
#                            'in_percentage_of_orders_with_fill or kill_lifetime': 0.0,
#                            'in_percentage_of_orders_with_good till cancel_lifetime': 0.0,
#                            'in_percentage_of_orders_with_good till time_lifetime': 0.0}}

# %% [markdown]
# ### bi_viz_5_price_instruction

# %%
# bi_viz_5_price_instruction = {}
# price_instruction_types = df_data['PriceInstruction'].unique()
# for pi in price_instruction_types:
#     counts = df_data['PriceInstruction'].value_counts()
#     bi_viz_5_price_instruction[f'number_of_orders_with_{pi.lower()}_price_instruction'] = counts.get(pi, 0)
#     bi_viz_5_price_instruction[f'percentage_of_orders_with_{pi.lower()}_price_instruction'] = round(counts.get(pi, 0) / len(df_data) * 100, 2)
# bi_viz_5_price_instruction


bi_viz_5_price_instruction = {'current': {}, 'average_historical': {}, 'percentage_difference': {}}
price_instruction_types = df_data['PriceInstruction'].unique()
counts = calculation_data['PriceInstruction'].value_counts()
historical_counts = historical_data['PriceInstruction'].value_counts()

for pi in price_instruction_types:
    # Current data calculations
    bi_viz_5_price_instruction['current'][f'number_of_orders_with_{pi.lower()}_price_instruction'] = counts.get(pi, 0)
    bi_viz_5_price_instruction['current'][f'percentage_of_orders_with_{pi.lower()}_price_instruction'] = round(
        counts.get(pi, 0) / len(calculation_data) * 100, 2
    )

    # Historical data calculations
    bi_viz_5_price_instruction['average_historical'][f'number_of_orders_with_{pi.lower()}_price_instruction'] = int(
        historical_counts.get(pi, 0) / historical_num_of_days
    )
    bi_viz_5_price_instruction['average_historical'][f'percentage_of_orders_with_{pi.lower()}_price_instruction'] = round(
        historical_counts.get(pi, 0) / len(historical_data) * 100, 2
    )

    # Percentage difference calculations
    bi_viz_5_price_instruction['percentage_difference'][f'in_number_of_orders_with_{pi.lower()}_price_instruction'] = calculate_percentage_difference(
        bi_viz_5_price_instruction['current'][f'number_of_orders_with_{pi.lower()}_price_instruction'],
        bi_viz_5_price_instruction['average_historical'][f'number_of_orders_with_{pi.lower()}_price_instruction']
    )
    bi_viz_5_price_instruction['percentage_difference'][f'in_percentage_of_orders_with_{pi.lower()}_price_instruction'] = calculate_percentage_difference(
        bi_viz_5_price_instruction['current'][f'percentage_of_orders_with_{pi.lower()}_price_instruction'],
        bi_viz_5_price_instruction['average_historical'][f'percentage_of_orders_with_{pi.lower()}_price_instruction']
    )
pprint(bi_viz_5_price_instruction)
# Out:
# {'average_historical': {'number_of_orders_with_limit_price_instruction': 2525,
#                         'number_of_orders_with_market on close_price_instruction': 2475,
#                         'percentage_of_orders_with_limit_price_instruction': 50.5,
#                         'percentage_of_orders_with_market on close_price_instruction': 49.5},
#  'current': {'number_of_orders_with_limit_price_instruction': 2525,
#              'number_of_orders_with_market on close_price_instruction': 2475,
#              'percentage_of_orders_with_limit_price_instruction': 50.5,
#              'percentage_of_orders_with_market on close_price_instruction': 49.5},
#  'percentage_difference': {'in_number_of_orders_with_limit_price_instruction': 0.0,
#                            'in_number_of_orders_with_market on close_price_instruction': 0.0,
#                            'in_percentage_of_orders_with_limit_price_instruction': 0.0,
#                            'in_percentage_of_orders_with_market on close_price_instruction': 0.0}}

# %% [markdown]
# ### bi_viz_6_trades_created_over_time

# %%
df_data['order_create_date_rounded_to_nearest_hour'] = df_data['CreateDate'].dt.floor('H')
trade_counts = df_data.groupby('order_create_date_rounded_to_nearest_minute').size()
trade_counts_df = trade_counts.reset_index(name='trade_count')
trade_counts_df.sort_values(by='order_create_date_rounded_to_nearest_minute', inplace=True)
total_trades = trade_counts_df['trade_count'].sum()
trade_counts_df['percentage_of_total_trade_count'] = round((trade_counts_df['trade_count'] / total_trades) * 100, 2)
trade_counts_df['absolute_change_of_trade_count_from_prev_minute'] = trade_counts_df['trade_count'].diff()
trade_counts_df
# Out:
#     order_create_date_rounded_to_nearest_minute  trade_count  \
# 0                           2024-02-01 11:33:00            4
# 1                           2024-02-01 11:34:00           15
# 2                           2024-02-01 11:35:00            9
# 3                           2024-02-01 11:36:00            9
# 4                           2024-02-01 11:37:00           14
# ..                                          ...          ...
# 404                         2024-02-01 18:17:00           10
# 405                         2024-02-01 18:18:00           11
# 406                         2024-02-01 18:19:00           10
# 407                         2024-02-01 18:20:00           13
# 408                         2024-02-01 18:21:00           19
#
#      percentage_of_total_trade_count  \
# 0                               0.08
# 1                               0.30
# 2                               0.18
# 3                               0.18
# 4                               0.28
# ..                               ...
# 404                             0.20
# 405                             0.22
# 406                             0.20
# 407                             0.26
# 408                             0.38
#
#      absolute_change_of_trade_count_from_prev_minute
# 0                                                NaN
# 1                                               11.0
# 2                                               -6.0
# 3                                                0.0
# 4                                                5.0
# ..                                               ...
# 404                                             -2.0
# 405                                              1.0
# 406                                             -1.0
# 407                                              3.0
# 408                                              6.0
#
# [409 rows x 4 columns]

# %% [markdown]
# ### bi_viz_7_sankey_diagram

# %%
bi_viz_7_sankey_diagram = {}
sector_types = df_data['SecCode'].unique()

total_counts = df_data['SecCode'].value_counts(normalize=True)
buy_counts = df_data[df_data['BuySell']=='Buy']['SecCode'].value_counts(normalize=True)
sell_counts = df_data[df_data['BuySell']=='Sell']['SecCode'].value_counts(normalize=True)
for sector in sector_types:
    bi_viz_7_sankey_diagram[sector] = {}
    bi_viz_7_sankey_diagram[sector]['percentage_of_{sector}_accounts_in_total_orders'] = round(total_counts.get(sector, 0) * 100, 2)
    bi_viz_7_sankey_diagram[sector]['percentage_of_{sector}_accounts_in_buy_orders'] = round(buy_counts.get(sector, 0) * 100, 2)
    bi_viz_7_sankey_diagram[sector]['percentage_of_{sector}_accounts_in_sell_orders'] = round(sell_counts.get(sector, 0) * 100, 2)
bi_viz_7_sankey_diagram
# Out:
# {'BHP': {'percentage_of_{sector}_accounts_in_total_orders': 12.7,
#   'percentage_of_{sector}_accounts_in_buy_orders': 12.95,
#   'percentage_of_{sector}_accounts_in_sell_orders': 12.45},
#  'NXT': {'percentage_of_{sector}_accounts_in_total_orders': 12.02,
#   'percentage_of_{sector}_accounts_in_buy_orders': 11.78,
#   'percentage_of_{sector}_accounts_in_sell_orders': 12.25},
#  'PEN': {'percentage_of_{sector}_accounts_in_total_orders': 12.32,
#   'percentage_of_{sector}_accounts_in_buy_orders': 12.63,
#   'percentage_of_{sector}_accounts_in_sell_orders': 12.01},
#  'CBA': {'percentage_of_{sector}_accounts_in_total_orders': 13.28,
#   'percentage_of_{sector}_accounts_in_buy_orders': 13.8,
#   'percentage_of_{sector}_accounts_in_sell_orders': 12.77},
#  'IRE': {'percentage_of_{sector}_accounts_in_total_orders': 12.4,
#   'percentage_of_{sector}_accounts_in_buy_orders': 12.83,
#   'percentage_of_{sector}_accounts_in_sell_orders': 11.97},
#  'JBH': {'percentage_of_{sector}_accounts_in_total_orders': 12.46,
#   'percentage_of_{sector}_accounts_in_buy_orders': 11.42,
#   'percentage_of_{sector}_accounts_in_sell_orders': 13.48},
#  'SIG': {'percentage_of_{sector}_accounts_in_total_orders': 11.94,
#   'percentage_of_{sector}_accounts_in_buy_orders': 12.15,
#   'percentage_of_{sector}_accounts_in_sell_orders': 11.74},
#  'ACDC': {'percentage_of_{sector}_accounts_in_total_orders': 12.88,
#   'percentage_of_{sector}_accounts_in_buy_orders': 12.43,
#   'percentage_of_{sector}_accounts_in_sell_orders': 13.32}}

# %%
I'm trying to do auto report generation to guide the readers in reading a dahsboard. The code above contains the code to geenrate the same summary information that is avaialble in the dashboard. How can I structure and pass all these data into a LLM so that it can use these figures to geenrate a report?

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 27
#       1 report_data = {
#       2     "overview": {
#       3         "total_number_orders_place": bi_viz_1_overview['total_number_orders_place'],
#       4         "total_volume_orders_place": bi_viz_1_overview['total_volume_orders_place'],
#       5         "total_value_orders_place": bi_viz_1_overview['total_value_orders_place']
#       6     },
#       7     "sector_analysis": {
#       8         sec: {
#       9             "number_of_buy": bi_viz_2_sector[sec]['number_of_buy_for_{}_sector'.format(sec)],
#      10             "percentage_of_buy": bi_viz_2_sector[sec]['percentage_of_buy_for_{}_sector'.format(sec)],
#      11             "number_of_sell": bi_viz_2_sector[sec]['number_of_sell_for_{}_sector'.format(sec)],
#      12             "percentage_of_sell": bi_viz_2_sector[sec]['percentage_of_sell_for_{}_sector'.format(sec)],
#      13             "total_number_of_order": bi_viz_2_sector[sec]['total_number_of_order']
#      14         }
#      15         for sec in bi_viz_2_sector.keys()
#      16     },
#      17     "capacity": {
#      18         "agency": {
#      19             "number_of_orders": bi_viz_3_capacity['number_of_orders_with_agency_capacity'],
#      20             "percentage": bi_viz_3_capacity['percentage_of_orders_with_agency_capacity']
#      21         },
#      22         "principal": {
#      23             "number_of_orders": bi_viz_3_capacity['number_of_orders_with_principal_capacity'],
#      24             "percentage": bi_viz_3_capacity['percentage_of_orders_with_principal_capacity']
#      25         }
#      26     },
# ---> 27     "lifetime": {
#      28         lifetime: {
#      29             "number_of_orders": bi_viz_4_lifetime['number_of_orders_with_{}_lifetime'.format(lifetime)],
#      30             "percentage": bi_viz_4_lifetime['percentage_of_orders_with_{}_lifetime'.format(lifetime)]
#      31         }
#      32         for lifetime in bi_viz_4_lifetime.keys()
#      33     },
#      34     "price_instruction": {
#      35         pi: {
#      36             "number_of_orders": bi_viz_5_price_instruction['number_of_orders_with_{}_price_instruction'.format(pi)],
#      37             "percentage": bi_viz_5_price_instruction['percentage_of_orders_with_{}_price_instruction'.format(pi)]
#      38         }
#      39         for pi in bi_viz_5_price_instruction.keys()
#      40     },
#      41     "trades_over_time": trade_counts_df.to_dict(orient='records'),  # Convert DataFrame to a list of dictionaries
#      42     "sankey_diagram": {
#      43         sec: {
#      44             "percentage_of_accounts_in_total_orders": round(total_counts.get(sec, 0) * 100, 2),
#      45             "percentage_of_accounts_in_buy_orders": round(buy_counts.get(sec, 0) * 100, 2),
#      46             "percentage_of_accounts_in_sell_orders": round(sell_counts.get(sec, 0) * 100, 2)
#      47         }
#      48         for sec in df_data['SecCode'].unique()
#      49     }
#      50 }
#
# Cell In[49], line 29, in <dictcomp>(.0)
#       1 report_data = {
#       2     "overview": {
#       3         "total_number_orders_place": bi_viz_1_overview['total_number_orders_place'],
#       4         "total_volume_orders_place": bi_viz_1_overview['total_volume_orders_place'],
#       5         "total_value_orders_place": bi_viz_1_overview['total_value_orders_place']
#       6     },
#       7     "sector_analysis": {
#       8         sec: {
#       9             "number_of_buy": bi_viz_2_sector[sec]['number_of_buy_for_{}_sector'.format(sec)],
#      10             "percentage_of_buy": bi_viz_2_sector[sec]['percentage_of_buy_for_{}_sector'.format(sec)],
#      11             "number_of_sell": bi_viz_2_sector[sec]['number_of_sell_for_{}_sector'.format(sec)],
#      12             "percentage_of_sell": bi_viz_2_sector[sec]['percentage_of_sell_for_{}_sector'.format(sec)],
#      13             "total_number_of_order": bi_viz_2_sector[sec]['total_number_of_order']
#      14         }
#      15         for sec in bi_viz_2_sector.keys()
#      16     },
#      17     "capacity": {
#      18         "agency": {
#      19             "number_of_orders": bi_viz_3_capacity['number_of_orders_with_agency_capacity'],
#      20             "percentage": bi_viz_3_capacity['percentage_of_orders_with_agency_capacity']
#      21         },
#      22         "principal": {
#      23             "number_of_orders": bi_viz_3_capacity['number_of_orders_with_principal_capacity'],
#      24             "percentage": bi_viz_3_capacity['percentage_of_orders_with_principal_capacity']
#      25         }
#      26     },
#      27     "lifetime": {
#      28         lifetime: {
# ---> 29             "number_of_orders": bi_viz_4_lifetime['number_of_orders_with_{}_lifetime'.format(lifetime)],
#      30             "percentage": bi_viz_4_lifetime['percentage_of_orders_with_{}_lifetime'.format(lifetime)]
#      31         }
#      32         for lifetime in bi_viz_4_lifetime.keys()
#      33     },
#      34     "price_instruction": {
#      35         pi: {
#      36             "number_of_orders": bi_viz_5_price_instruction['number_of_orders_with_{}_price_instruction'.format(pi)],
#      37             "percentage": bi_viz_5_price_instruction['percentage_of_orders_with_{}_price_instruction'.format(pi)]
#      38         }
#      39         for pi in bi_viz_5_price_instruction.keys()
#      40     },
#      41     "trades_over_time": trade_counts_df.to_dict(orient='records'),  # Convert DataFrame to a list of dictionaries
#      42     "sankey_diagram": {
#      43         sec: {
#      44             "percentage_of_accounts_in_total_orders": round(total_counts.get(sec, 0) * 100, 2),
#      45             "percentage_of_accounts_in_buy_orders": round(buy_counts.get(sec, 0) * 100, 2),
#      46             "percentage_of_accounts_in_sell_orders": round(sell_counts.get(sec, 0) * 100, 2)
#      47         }
#      48         for sec in df_data['SecCode'].unique()
#      49     }
#      50 }
#
# KeyError: 'number_of_orders_with_number_of_orders_with_good till cancel_lifetime_lifetime'
