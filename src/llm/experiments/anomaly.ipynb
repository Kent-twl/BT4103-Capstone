# %% [markdown]
# **Notebook for experimenting with prompts**

# %%
## Imports
## System imports
import os
import sys

ROOT_DIR = os.path.join(os.path.dirname(os.getcwd()), os.pardir, os.pardir)
sys.path.append(ROOT_DIR)
sys.path.append(ROOT_DIR + "/src")
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), "../")) ## LLM directory

## Data manipulation
import pandas as pd

## LangChain
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage

## Misc
from dotenv import load_dotenv
from datetime import datetime
from pprint import pprint

## Self-defined modules
from src.llm.utils import calculations
from src.llm.prompts import dashboard_prompts, variable_descriptions
import anomaly

# %% [markdown]
# API keys (retrieved from .env file)

# %%
## Load environment variables
load_dotenv()
assert os.environ['LANGCHAIN_API_KEY'], "Please set the LANGCHAIN_API_KEY environment variable"
assert os.environ['OPENAI_API_KEY'], "Please set the OPENAI_API_KEY environment variable"

# %%
## Configuring LLM
openai_llm = ChatOpenAI(model="gpt-4o-mini", api_key=os.environ['OPENAI_API_KEY'])

# %%
## Run anomaly detection model
continuous_outlier_df, discrete_outlier_df, overall_anomaly_results = anomaly.main();

# %%
print(overall_anomaly_results)
# Out:
#       Unnamed: 0    Instance    OrderNo  ParentOrderNo  RootParentOrderNo  \
# 485          485  BURGERKING  172374515       25869076          226102108
# 708          708  BURGERKING   72375304       16501749          570372666
# 719          719  BURGERKING   72374535       60528598          585916882
# 2053        2053  BURGERKING  172370932       53710462          562953313
# 2372        2372  BURGERKING  172374752       14801087          572610220
# 2860        2860  BURGERKING  172373762       26663556          659348535
# 4671        4671  BURGERKING   72372809       11804334           76882466
#
#               CreateDate           DeleteDate  AccID  AccCode BuySell  ...  \
# 485  2024-10-09 10:27:10  2024-02-01 15:03:52    173     NOEL       S  ...
# 708  2024-10-09 10:39:03  2024-02-01 17:41:14    172       ZM       B  ...
# 719  2024-10-09 10:39:57  2024-02-01 17:52:28      5     NOEL       B  ...
# 2053 2024-10-09 11:55:07  2024-02-01 11:37:44     80  UNKNOWN       S  ...
# 2372 2024-10-09 12:37:20  2024-02-01 12:02:47    156     NOEL       B  ...
# 2860 2024-10-09 13:52:23  2024-02-01 13:56:34     13    ROBBO       S  ...
# 4671 2024-10-09 15:42:45  2024-02-01 13:03:20    150     NOEL       S  ...
#
#       OrderTakerUserCode IntermediaryID  OriginOfOrder OrderCapacity  \
# 485        admin@IRETEST   114051.07860     ROBTESTING        Agency
# 708      admin@ROBBOTEST    26429.23879           NOEL        Agency
# 719        admin@IRETEST   107496.43930             HK        Agency
# 2053     admin@ROBBOTEST    71711.42616             39     Principal
# 2372       admin@IRETEST   108441.66050             HK     Principal
# 2860     admin@ROBBOTEST   122585.45800           NOEL     Principal
# 4671       admin@IRETEST    13550.12176             HK     Principal
#
#      DirectedWholesale ExecutionVenue  \
# 485                  N       0.479371
# 708                  N       0.855916
# 719                  N       0.848705
# 2053                 N       0.201428
# 2372                 N       0.300070
# 2860                 N       0.499659
# 4671                 N       0.700788
#
#                                ExecutionInstructionsRaw  top_feature_1  \
# 485                  IADW(N), IOCA(Agency), IAOR(34976)      AccID_173
# 708          IAOR(TESTINGACC), IOCA(Principal), IADW(N)      AccID_172
# 719             IAOR(TESTINGACC), IOCA(Agency), IADW(N)        AccID_5
# 2053  IAOR(ROBTESTING), IOCA(Agency), IADW(N), IAIN(...    SecCode_S32
# 2372  IAOR(ROBTESTING), IOCA(Agency), IADW(N), IAIN(...      AccID_156
# 2860            IAOR(TESTINGACC), IOCA(Agency), IADW(N)       AccID_13
# 4671  IAOR(ROBTESTING), IOCA(Agency), IADW(N), IAIN(...      DoneValue
#
#            top_feature_2       top_feature_3
# 485         AccCode_NOEL               Value
# 708          SecCode_SEK  OriginOfOrder_NOEL
# 719         AccCode_NOEL               Value
# 2053           DoneValue          DoneVolume
# 2372           DoneValue               Value
# 2860  OriginOfOrder_NOEL         SecCode_BSL
# 4671        AccCode_NOEL               Value
#
# [7 rows x 44 columns]

# %% [markdown]
# **Prompts**

# %% [markdown]
# Use PromptTemplate to create a prompt, specifying the input variables to be replaced by data

# %%
filtered_anomaly_results = overall_anomaly_results[['OrderNo', 'top_feature_1', 'top_feature_2', 'top_feature_3']]
anomalies_and_reasons = filtered_anomaly_results.to_dict(orient='records')
pprint(anomalies_and_reasons)

full_anomalies_and_reasons = overall_anomaly_results.to_dict(orient='records')
pprint(full_anomalies_and_reasons)
# Out:
# [{'OrderNo': 172374515,
#   'top_feature_1': 'AccID_173',
#   'top_feature_2': 'AccCode_NOEL',
#   'top_feature_3': 'Value'},
#  {'OrderNo': 72375304,
#   'top_feature_1': 'AccID_172',
#   'top_feature_2': 'SecCode_SEK',
#   'top_feature_3': 'OriginOfOrder_NOEL'},
#  {'OrderNo': 72374535,
#   'top_feature_1': 'AccID_5',
#   'top_feature_2': 'AccCode_NOEL',
#   'top_feature_3': 'Value'},
#  {'OrderNo': 172370932,
#   'top_feature_1': 'SecCode_S32',
#   'top_feature_2': 'DoneValue',
#   'top_feature_3': 'DoneVolume'},
#  {'OrderNo': 172374752,
#   'top_feature_1': 'AccID_156',
#   'top_feature_2': 'DoneValue',
#   'top_feature_3': 'Value'},
#  {'OrderNo': 172373762,
#   'top_feature_1': 'AccID_13',
#   'top_feature_2': 'OriginOfOrder_NOEL',
#   'top_feature_3': 'SecCode_BSL'},
#  {'OrderNo': 72372809,
#   'top_feature_1': 'DoneValue',
#   'top_feature_2': 'AccCode_NOEL',
#   'top_feature_3': 'Value'}]
# [{'AccCode': 'NOEL',
#   'AccID': 173,
#   'BuySell': 'S',
#   'ClientOrderID': 0.395855319,
#   'CreateDate': Timestamp('2024-10-09 10:27:10'),
#   'Currency': 'AUD',
#   'DeleteDate': '2024-02-01 15:03:52',
#   'DestOrderNo': 7517541426874009600,
#   'DestUserID': 3678,
#   'Destination': 'ASX',
#   'DirectedWholesale': 'N',
#   'DoneValue': 195907.8015720638,
#   'DoneVolume': 401,
#   'Exchange': 'AXW',
#   'ExecutionInstructionsRaw': 'IADW(N), IOCA(Agency), IAOR(34976)',
#   'ExecutionVenue': 0.4793710511,
#   'ExtDestOrderNo': '27Y19YXOG7UB',
#   'Instance': 'BURGERKING',
#   'IntermediaryID': 114051.0786,
#   'Lifetime': 'FAK',
#   'OrderCapacity': 'Agency',
#   'OrderGiver': 'robtest',
#   'OrderNo': 172374515,
#   'OrderSide': 'Buy',
#   'OrderTakerUserCode': 'admin@IRETEST',
#   'OrderType': 4,
#   'OriginOfOrder': 'ROBTESTING',
#   'ParentOrderNo': 25869076,
#   'Price': 488.5481335961691,
#   'PriceInstruction': 'Market On Close',
#   'PriceMultiplier': 0.01,
#   'Quantity': 15999,
#   'RootParentOrderNo': 226102108,
#   'SecCode': 'CBA',
#   'SecID': 957691438,
#   'SecondaryClientOrderID': 0.790597146,
#   'Side': 2,
#   'TimeInForce': 53,
#   'Unnamed: 0': 485,
#   'Value': 7816281.58940511,
#   'ValueMultiplier': 0.01,
#   'top_feature_1': 'AccID_173',
#   'top_feature_2': 'AccCode_NOEL',
#   'top_feature_3': 'Value'},
#  {'AccCode': 'ZM',
#   'AccID': 172,
#   'BuySell': 'B',
#   'ClientOrderID': 0.537224738,
#   'CreateDate': Timestamp('2024-10-09 10:39:03'),
#   'Currency': 'AUD',
#   'DeleteDate': '2024-02-01 17:41:14',
#   'DestOrderNo': 4687342336360890368,
#   'DestUserID': 3974,
#   'Destination': 'CXA',
#   'DirectedWholesale': 'N',
#   'DoneValue': 828127.3917951074,
#   'DoneVolume': 1738,
#   'Exchange': 'ASX',
#   'ExecutionInstructionsRaw': 'IAOR(TESTINGACC), IOCA(Principal), IADW(N)',
#   'ExecutionVenue': 0.8559163696,
#   'ExtDestOrderNo': '27Y19YXOG7UD',
#   'Instance': 'BURGERKING',
#   'IntermediaryID': 26429.23879,
#   'Lifetime': 'FAK',
#   'OrderCapacity': 'Agency',
#   'OrderGiver': 'robbotest',
#   'OrderNo': 72375304,
#   'OrderSide': 'Long Sell',
#   'OrderTakerUserCode': 'admin@ROBBOTEST',
#   'OrderType': 4,
#   'OriginOfOrder': 'NOEL',
#   'ParentOrderNo': 16501749,
#   'Price': 476.4829642089226,
#   'PriceInstruction': 'Limit',
#   'PriceMultiplier': 0.01,
#   'Quantity': 1755,
#   'RootParentOrderNo': 570372666,
#   'SecCode': 'SEK',
#   'SecID': 637372274,
#   'SecondaryClientOrderID': 0.7941427471,
#   'Side': 2,
#   'TimeInForce': 54,
#   'Unnamed: 0': 708,
#   'Value': 836227.6021866591,
#   'ValueMultiplier': 0.01,
#   'top_feature_1': 'AccID_172',
#   'top_feature_2': 'SecCode_SEK',
#   'top_feature_3': 'OriginOfOrder_NOEL'},
#  {'AccCode': 'NOEL',
#   'AccID': 5,
#   'BuySell': 'B',
#   'ClientOrderID': 0.4526322533,
#   'CreateDate': Timestamp('2024-10-09 10:39:57'),
#   'Currency': 'AUD',
#   'DeleteDate': '2024-02-01 17:52:28',
#   'DestOrderNo': 4141326185714809856,
#   'DestUserID': 476,
#   'Destination': 'ASX',
#   'DirectedWholesale': 'N',
#   'DoneValue': 1094907.122693059,
#   'DoneVolume': 2342,
#   'Exchange': 'AXW',
#   'ExecutionInstructionsRaw': 'IAOR(TESTINGACC), IOCA(Agency), IADW(N)',
#   'ExecutionVenue': 0.8487053041,
#   'ExtDestOrderNo': '17Y19YXOGMGT',
#   'Instance': 'BURGERKING',
#   'IntermediaryID': 107496.4393,
#   'Lifetime': 'EOD',
#   'OrderCapacity': 'Agency',
#   'OrderGiver': 'robtest',
#   'OrderNo': 72374535,
#   'OrderSide': 'Long Sell',
#   'OrderTakerUserCode': 'admin@IRETEST',
#   'OrderType': 3,
#   'OriginOfOrder': 'HK',
#   'ParentOrderNo': 60528598,
#   'Price': 467.5094460687696,
#   'PriceInstruction': 'Limit',
#   'PriceMultiplier': 0.01,
#   'Quantity': 18248,
#   'RootParentOrderNo': 585916882,
#   'SecCode': 'WES',
#   'SecID': 362576311,
#   'SecondaryClientOrderID': 0.3682099186,
#   'Side': 1,
#   'TimeInForce': 25,
#   'Unnamed: 0': 719,
#   'Value': 8531112.371862909,
#   'ValueMultiplier': 0.01,
#   'top_feature_1': 'AccID_5',
#   'top_feature_2': 'AccCode_NOEL',
#   'top_feature_3': 'Value'},
#  {'AccCode': 'UNKNOWN',
#   'AccID': 80,
#   'BuySell': 'S',
#   'ClientOrderID': 0.8315185398,
#   'CreateDate': Timestamp('2024-10-09 11:55:07'),
#   'Currency': 'AUD',
#   'DeleteDate': '2024-02-01 11:37:44',
#   'DestOrderNo': 2679147472907789824,
#   'DestUserID': 4477,
#   'Destination': 'CXA',
#   'DirectedWholesale': 'N',
#   'DoneValue': 7086256.260748141,
#   'DoneVolume': 14112,
#   'Exchange': 'ASX',
#   'ExecutionInstructionsRaw': 'IAOR(ROBTESTING), IOCA(Agency), IADW(N), '
#                               'IAIN(123456)',
#   'ExecutionVenue': 0.2014276316,
#   'ExtDestOrderNo': '27Y19YXOGV80',
#   'Instance': 'BURGERKING',
#   'IntermediaryID': 71711.42616,
#   'Lifetime': 'FAK',
#   'OrderCapacity': 'Principal',
#   'OrderGiver': 'robbotest',
#   'OrderNo': 172370932,
#   'OrderSide': 'Buy',
#   'OrderTakerUserCode': 'admin@ROBBOTEST',
#   'OrderType': 2,
#   'OriginOfOrder': 39,
#   'ParentOrderNo': 53710462,
#   'Price': 502.144009406756,
#   'PriceInstruction': 'Market On Close',
#   'PriceMultiplier': 0.01,
#   'Quantity': 15948,
#   'RootParentOrderNo': 562953313,
#   'SecCode': 'S32',
#   'SecID': 357179125,
#   'SecondaryClientOrderID': 0.8361247585,
#   'Side': 2,
#   'TimeInForce': 14,
#   'Unnamed: 0': 2053,
#   'Value': 8008192.662018945,
#   'ValueMultiplier': 0.01,
#   'top_feature_1': 'SecCode_S32',
#   'top_feature_2': 'DoneValue',
#   'top_feature_3': 'DoneVolume'},
#  {'AccCode': 'NOEL',
#   'AccID': 156,
#   'BuySell': 'B',
#   'ClientOrderID': 0.03268644714,
#   'CreateDate': Timestamp('2024-10-09 12:37:20'),
#   'Currency': 'AUD',
#   'DeleteDate': '2024-02-01 12:02:47',
#   'DestOrderNo': 4598391211661940224,
#   'DestUserID': 2046,
#   'Destination': 'ASX',
#   'DirectedWholesale': 'N',
#   'DoneValue': 6641840.422683054,
#   'DoneVolume': 13518,
#   'Exchange': 'ASX',
#   'ExecutionInstructionsRaw': 'IAOR(ROBTESTING), IOCA(Agency), IADW(N), '
#                               'IAIN(123456)',
#   'ExecutionVenue': 0.3000698723,
#   'ExtDestOrderNo': '17Y19YXOGMGT',
#   'Instance': 'BURGERKING',
#   'IntermediaryID': 108441.6605,
#   'Lifetime': 'GTC',
#   'OrderCapacity': 'Principal',
#   'OrderGiver': 'robbotest',
#   'OrderNo': 172374752,
#   'OrderSide': 'Short Sell',
#   'OrderTakerUserCode': 'admin@IRETEST',
#   'OrderType': 3,
#   'OriginOfOrder': 'HK',
#   'ParentOrderNo': 14801087,
#   'Price': 491.3330686997377,
#   'PriceInstruction': 'Market On Close',
#   'PriceMultiplier': 0.01,
#   'Quantity': 15382,
#   'RootParentOrderNo': 572610220,
#   'SecCode': 'CPU',
#   'SecID': 256260450,
#   'SecondaryClientOrderID': 0.1371876611,
#   'Side': 1,
#   'TimeInForce': 2,
#   'Unnamed: 0': 2372,
#   'Value': 7557685.262739365,
#   'ValueMultiplier': 0.01,
#   'top_feature_1': 'AccID_156',
#   'top_feature_2': 'DoneValue',
#   'top_feature_3': 'Value'},
#  {'AccCode': 'ROBBO',
#   'AccID': 13,
#   'BuySell': 'S',
#   'ClientOrderID': 0.4157633887,
#   'CreateDate': Timestamp('2024-10-09 13:52:23'),
#   'Currency': 'AUD',
#   'DeleteDate': '2024-02-01 13:56:34',
#   'DestOrderNo': 1304192306890939904,
#   'DestUserID': 3184,
#   'Destination': 'ASX',
#   'DirectedWholesale': 'N',
#   'DoneValue': 811365.9088509431,
#   'DoneVolume': 3806,
#   'Exchange': 'AXW',
#   'ExecutionInstructionsRaw': 'IAOR(TESTINGACC), IOCA(Agency), IADW(N)',
#   'ExecutionVenue': 0.4996592433,
#   'ExtDestOrderNo': '27Y19YXOGV80',
#   'Instance': 'BURGERKING',
#   'IntermediaryID': 122585.458,
#   'Lifetime': 'EOD',
#   'OrderCapacity': 'Principal',
#   'OrderGiver': 'robbotest',
#   'OrderNo': 172373762,
#   'OrderSide': 'Buy',
#   'OrderTakerUserCode': 'admin@ROBBOTEST',
#   'OrderType': 4,
#   'OriginOfOrder': 'NOEL',
#   'ParentOrderNo': 26663556,
#   'Price': 213.1807432608889,
#   'PriceInstruction': 'Limit',
#   'PriceMultiplier': 0.01,
#   'Quantity': 4234,
#   'RootParentOrderNo': 659348535,
#   'SecCode': 'BSL',
#   'SecID': 894656197,
#   'SecondaryClientOrderID': 0.4902156611,
#   'Side': 4,
#   'TimeInForce': 33,
#   'Unnamed: 0': 2860,
#   'Value': 902607.2669666035,
#   'ValueMultiplier': 0.01,
#   'top_feature_1': 'AccID_13',
#   'top_feature_2': 'OriginOfOrder_NOEL',
#   'top_feature_3': 'SecCode_BSL'},
#  {'AccCode': 'NOEL',
#   'AccID': 150,
#   'BuySell': 'S',
#   'ClientOrderID': 0.08232045408,
#   'CreateDate': Timestamp('2024-10-09 15:42:45'),
#   'Currency': 'AUD',
#   'DeleteDate': '2024-02-01 13:03:20',
#   'DestOrderNo': 6724372262588269568,
#   'DestUserID': 1763,
#   'Destination': 'ASX',
#   'DirectedWholesale': 'N',
#   'DoneValue': 6613373.486385785,
#   'DoneVolume': 13398,
#   'Exchange': 'AXW',
#   'ExecutionInstructionsRaw': 'IAOR(ROBTESTING), IOCA(Agency), IADW(N), '
#                               'IAIN(123456)',
#   'ExecutionVenue': 0.7007884999,
#   'ExtDestOrderNo': '17Y19YXOID1C',
#   'Instance': 'BURGERKING',
#   'IntermediaryID': 13550.12176,
#   'Lifetime': 'GTC',
#   'OrderCapacity': 'Principal',
#   'OrderGiver': 'robtest',
#   'OrderNo': 72372809,
#   'OrderSide': 'Short Sell',
#   'OrderTakerUserCode': 'admin@IRETEST',
#   'OrderType': 2,
#   'OriginOfOrder': 'HK',
#   'ParentOrderNo': 11804334,
#   'Price': 493.6090077911468,
#   'PriceInstruction': 'Market On Close',
#   'PriceMultiplier': 0.01,
#   'Quantity': 15795,
#   'RootParentOrderNo': 76882466,
#   'SecCode': 'CBA',
#   'SecID': 244319483,
#   'SecondaryClientOrderID': 0.337292089,
#   'Side': 2,
#   'TimeInForce': 36,
#   'Unnamed: 0': 4671,
#   'Value': 7796554.278061165,
#   'ValueMultiplier': 0.01,
#   'top_feature_1': 'DoneValue',
#   'top_feature_2': 'AccCode_NOEL',
#   'top_feature_3': 'Value'}]

# %%
anomaly_prompt = PromptTemplate.from_template(dashboard_prompts.anomaly_dash_prompt)\
    .format(anomalies_and_reasons=anomalies_and_reasons)
pprint(anomaly_prompt)
# Out:
# ('\n'
#  'This particular chart is part of an Anomaly Detection dashboard.\n'
#  'It is used by compliance officers to identify suspicious trading '
#  'activities.\n'
#  'The chart is generated after running the order data through an anomaly '
#  'detection model.\n'
#  'Write a description for this chart, with reference to the following list of '
#  'flagged orders and the respective reasons they were flagged:\n'
#  "[{'OrderNo': 172374515, 'top_feature_1': 'AccID_173', 'top_feature_2': "
#  "'AccCode_NOEL', 'top_feature_3': 'Value'}, {'OrderNo': 72375304, "
#  "'top_feature_1': 'AccID_172', 'top_feature_2': 'SecCode_SEK', "
#  "'top_feature_3': 'OriginOfOrder_NOEL'}, {'OrderNo': 72374535, "
#  "'top_feature_1': 'AccID_5', 'top_feature_2': 'AccCode_NOEL', "
#  "'top_feature_3': 'Value'}, {'OrderNo': 172370932, 'top_feature_1': "
#  "'SecCode_S32', 'top_feature_2': 'DoneValue', 'top_feature_3': 'DoneVolume'}, "
#  "{'OrderNo': 172374752, 'top_feature_1': 'AccID_156', 'top_feature_2': "
#  "'DoneValue', 'top_feature_3': 'Value'}, {'OrderNo': 172373762, "
#  "'top_feature_1': 'AccID_13', 'top_feature_2': 'OriginOfOrder_NOEL', "
#  "'top_feature_3': 'SecCode_BSL'}, {'OrderNo': 72372809, 'top_feature_1': "
#  "'DoneValue', 'top_feature_2': 'AccCode_NOEL', 'top_feature_3': 'Value'}]\n")

# %%
messages = [
    SystemMessage(content=dashboard_prompts.system_prompt),
    HumanMessage(content=anomaly_prompt)
]
response = openai_llm.invoke(messages)
print(response.content)
# Out:
# **Anomaly Detection Chart Description**
#
# This chart visualizes flagged trading orders identified by our anomaly detection model, facilitating compliance officers in monitoring and investigating suspicious activities. Each entry on the chart represents an order that has been flagged based on specific features that deviate from expected patterns.
#
# - **Order Number 172374515**: Flagged due to unusual activity associated with **Account ID 173** and **Account Code NOEL**, indicating potential discrepancies in the order's value.
#
# - **Order Number 72375304**: This order was highlighted for its connection to **Account ID 172** and the security code **SEK**, with the origin of the order marked as suspicious (**OriginOfOrder_NOEL**).
#
# - **Order Number 72374535**: Similar to the previous orders, this entry is linked to **Account ID 5** and **Account Code NOEL**, raising concerns regarding its reported value.
#
# - **Order Number 172370932**: This transaction has been flagged for its association with the security code **S32**, with anomalies detected in both the **Done Value** and **Done Volume**.
#
# - **Order Number 172374752**: Marked for scrutiny, this order relates to **Account ID 156** and showcases irregularities between its **Done Value** and the reported **Value**.
#
# - **Order Number 172373762**: Highlighted for its association with **Account ID 13**, this order shows unusual activity concerning **OriginOfOrder_NOEL** and the security code **BSL**.
#
# - **Order Number 72372809**: This entry raises flags due to anomalies detected in the **Done Value**, linked to **Account Code NOEL** and its order value.
#
# The visual representation of these flagged orders allows compliance officers to quickly identify and prioritize investigations into potentially harmful trading activities, ensuring the institution maintains regulatory compliance and mitigates risks associated with anomalous trading patterns.

# %%
## Try again with all columns
full_anomaly_prompt = PromptTemplate.from_template(dashboard_prompts.anomaly_dash_prompt)\
    .format(anomalies_and_reasons=full_anomalies_and_reasons)

messages = [
    SystemMessage(content=dashboard_prompts.system_prompt),
    HumanMessage(content=full_anomaly_prompt)
]
response = openai_llm.invoke(messages)
print(response.content)
# Out:
# ### Anomaly Detection Chart Overview
#
# The Anomaly Detection Chart provides compliance officers with a critical tool for identifying suspicious trading activities within our institution. This visualization utilizes advanced anomaly detection algorithms applied to the institution's order data, highlighting transactions that deviate significantly from established patterns.
#
# Each flagged order is represented in the chart, accompanied by key attributes that shed light on the nature of the anomaly. For instance, orders may be flagged based on unusual transaction values, atypical account codes, or striking buy/sell patterns. In the data set, we can see several flagged orders with specific reasons for their identification:
#
# 1. **Order No. 172374515**: Flagged due to an unusually high transaction value of approximately AUD 7.8 million, associated with Account ID 173 and a sell action for security CBA.
#
# 2. **Order No. 72375304**: This order was highlighted for its significant volume and value, amounting to around AUD 836,227, which is atypical for Account ID 172, involved in a long sell of security SEK.
#
# 3. **Order No. 72374535**: Another notable entry, this order involved a long sell of security WES, with a total value of AUD 8.5 million, raising flags for Account ID 5 due to its scale and nature.
#
# 4. **Order No. 172370932**: Flagged for being a high-value market order (AUD 8 million) from an account with an ambiguous code 'UNKNOWN,' indicating potential irregularities in account identification.
#
# 5. **Order No. 172374752**: This short sell order for security CPU, worth over AUD 7.5 million, raised concerns due to its value and the account's historical activity.
#
# 6. **Order No. 172373762**: Another flagged entry, this buy order was worth nearly AUD 903,000, associated with Account ID 13, which reflects atypical trading behavior.
#
# 7. **Order No. 72372809**: This short sell of security CBA for around AUD 7.8 million was noted for its significant value and the account's nature, suggesting possible market manipulation.
#
# The chart not only displays these flagged orders but also offers insights into their respective characteristics, such as transaction volume, account codes, and execution venues. By analyzing these anomalies, compliance officers can conduct further investigations to ensure adherence to regulatory standards and mitigate potential risks associated with fraudulent trading activities.
